# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-10e4c32f-b154-46c0-8f31-f1ebe294dc67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10e4c32f-b154-46c0-8f31-f1ebe294dc67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import io

print(uploaded.keys())

if 'udemy.csv' in uploaded:

    df = pd.read_csv(io.BytesIO(uploaded['udemy.csv']))

    print(df)
else:
    print("Error: 'udemy.csv' not found in the uploaded files.")
# Out:
# dict_keys(['udemy.csv'])
#                                             course_name  \
# 0     2022 Complete Python Bootcamp From Zero to Her...
# 1                       The Web Developer Bootcamp 2022
# 2            The Complete 2022 Web Development Bootcamp
# 3           Angular - The Complete Guide (2023 Edition)
# 4     Java Programming Masterclass covering Java 11 ...
# ...                                                 ...
# 5022  Siemens WinCC SCADA Programming, SCADA1 ( Basic )
# 5023  Python Object Oriented Programming (OOP): Begi...
# 5024                                jQuery Basics Guide
# 5025  Introduction to Android Development for beginners
# 5026                                                NaN
#
#                                              instructor  \
# 0                                         Jose Portilla
# 1                                           Colt Steele
# 2                                         Dr. Angela Yu
# ...

# %%
df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5027 entries, 0 to 5026
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   course_name           5013 non-null   object
#  1   instructor            5016 non-null   object
#  2   course url            5020 non-null   object
#  3   course image          5017 non-null   object
#  4   course description    5016 non-null   object
#  5   reviews_avg           5017 non-null   object
#  6   reviews_count         5017 non-null   object
#  7   course_duration       5017 non-null   object
#  8   lectures_count        5017 non-null   object
#  9   level                 5017 non-null   object
#  10  price_after_discount  5017 non-null   object
#  11  main_price            4799 non-null   object
#  12  course_flag           518 non-null    object
#  13  students_count        5013 non-null   object
#  14  Unnamed: 14           3 non-null      object
# ...

# %%
df.columns
# Out:
# Index(['course_name', 'instructor', 'course url', 'course image',
#        'course description', 'reviews_avg', 'reviews_count', 'course_duration',
#        'lectures_count', 'level', 'price_after_discount', 'main_price',
#        'course_flag', 'students_count', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17'],
#       dtype='object')

# %%
df.drop(['Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#                                          course_name  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
# 5  React - The Complete Guide (incl Hooks, React ...
# 6  Machine Learning A-Z™: Hands-On Python & R In ...
# 7  The Complete JavaScript Course 2023: From Zero...
# 8  100 Days of Code: The Complete Python Pro Boot...
# 9  Python for Data Science and Machine Learning B...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
# 5  Academind by Maximilian Schwarzmüller, Maximil...
# ...

# %%
print(df.isnull().sum())
# Out:
# course_name               14
# instructor                11
# course url                 7
# course image              10
# course description        11
# reviews_avg               10
# reviews_count             10
# course_duration           10
# lectures_count            10
# level                     10
# price_after_discount      10
# main_price               228
# course_flag             4509
# students_count            14
# dtype: int64

# %%
df.dropna(subset=['course_name', 'instructor', 'course url', 'course image', 'course description', 'reviews_avg', 'reviews_count', 'course_duration', 'lectures_count', 'level', 'price_after_discount', 'students_count'], inplace=True)

df.drop(['course_flag', 'main_price'], axis=1, inplace=True)


print(df.isnull().sum())
# Out:
# course_name             0
# instructor              0
# course url              0
# course image            0
# course description      0
# reviews_avg             0
# reviews_count           0
# course_duration         0
# lectures_count          0
# level                   0
# price_after_discount    0
# students_count          0
# dtype: int64

# %%
df.dropna(axis=1, how='all', inplace=True)

print(df.columns)
# Out:
# Index(['course_name', 'instructor', 'course url', 'course image',
#        'course description', 'reviews_avg', 'reviews_count', 'course_duration',
#        'lectures_count', 'level', 'price_after_discount', 'students_count'],
#       dtype='object')

# %%
df.head(10)
# Out:
#                                          course_name  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
# 5  React - The Complete Guide (incl Hooks, React ...
# 6  Machine Learning A-Z™: Hands-On Python & R In ...
# 7  The Complete JavaScript Course 2023: From Zero...
# 8  100 Days of Code: The Complete Python Pro Boot...
# 9  Python for Data Science and Machine Learning B...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
# 5  Academind by Maximilian Schwarzmüller, Maximil...
# ...

# %%
print(df.reviews_count.unique())
# Out:
# ['440383 reviews' '248508 reviews' '234837 reviews' ... '126 reviews'
#  '125 reviews' '124 reviews']

# %%
urls_as_reviews_count = df[df['reviews_count'].str.startswith('http')]

print(urls_as_reviews_count[['reviews_count', 'course url']])
# Out:
#                                          reviews_count course url
# 501  https://www.udemy.com/course/devops-fundamenta...    Jenkins

# %%
import re


df['reviews_count'] = df['reviews_count'].astype(str)

# Remove ' reviews' from the 'reviews_count' values
df['reviews_count'] = df['reviews_count'].str.replace(' reviews', '')

# Extract the numeric part using regular expressions
df['reviews_count'] = df['reviews_count'].str.extract('(\d+)')

# Convert 'reviews_count' to integer type
df['reviews_count'] = df['reviews_count'].astype(float).fillna(0).astype(int)

# %%
df.head(10)
# Out:
#                                          course_name  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
# 5  React - The Complete Guide (incl Hooks, React ...
# 6  Machine Learning A-Z™: Hands-On Python & R In ...
# 7  The Complete JavaScript Course 2023: From Zero...
# 8  100 Days of Code: The Complete Python Pro Boot...
# 9  Python for Data Science and Machine Learning B...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
# 5  Academind by Maximilian Schwarzmüller, Maximil...
# ...

# %%
df['reviews_avg'] = df['reviews_avg'].astype(str)
df['course_duration'] = df['course_duration'].astype(str)
df['lectures_count'] = df['lectures_count'].astype(str)
df['students_count'] = df['students_count'].astype(str)


df['reviews_avg'] = df['reviews_avg'].str.replace('Rating: ', '').str.extract('(\d+\.\d+|\d+)').astype(float)
df['course_duration'] = df['course_duration'].str.replace(' total hours', '').str.replace(' total hour', '')


df['lectures_count'] = df['lectures_count'].str.extract('(\d+)').astype(float)

df['students_count'] = df['students_count'].str.replace(' students', '').str.replace(',', '').str.extract('(\d+)').astype(float)

# %%
df.head(10)
# Out:
#                                          course_name  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
# 5  React - The Complete Guide (incl Hooks, React ...
# 6  Machine Learning A-Z™: Hands-On Python & R In ...
# 7  The Complete JavaScript Course 2023: From Zero...
# 8  100 Days of Code: The Complete Python Pro Boot...
# 9  Python for Data Science and Machine Learning B...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
# 5  Academind by Maximilian Schwarzmüller, Maximil...
# ...

# %%
df.drop('price_after_discount', axis=1, inplace=True)

# %%
df.head(5)
# Out:
#                                          course_name  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
#
#                                           course url  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-web-developer...
# 2  https://www.udemy.com/course/the-complete-web-...
# 3  https://www.udemy.com/course/the-complete-guid...
# ...

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Beginner', 'Intermediate', 'Expert',
#        'Rating: 4.5 out of 5', 'Current price: E£269.99',
#        'Current price: E£199.99', 'Current price: E£229.99'], dtype=object)

# %%
valid_levels = ['All Levels', 'Beginner', 'Intermediate', 'Expert']


df = df[df['level'].isin(valid_levels)]

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Beginner', 'Intermediate', 'Expert'], dtype=object)

# %%
df.columns
# Out:
# Index(['course_name', 'instructor', 'course url', 'course image',
#        'course description', 'reviews_avg', 'reviews_count', 'course_duration',
#        'lectures_count', 'level', 'students_count'],
#       dtype='object')

# %%
df.rename(columns={'students_count':'Number of Students', 'lectures_count':'Duration of lectures', 'reviews_avg':'Mean_review', 'reviews_count':'Number_of_reviews'}, inplace=True)
# Out:
# <ipython-input-25-9361c8da8db2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'students_count':'Number of Students', 'lectures_count':'Duration of lectures', 'reviews_avg':'Mean_review', 'reviews_count':'Number_of_reviews'}, inplace=True)

# %%
df.columns
# Out:
# Index(['course_name', 'instructor', 'course url', 'course image',
#        'course description', 'Mean_review', 'Number_of_reviews',
#        'course_duration', 'Duration of lectures', 'level',
#        'Number of Students'],
#       dtype='object')

# %%
df_sorted = df.sort_values(by='Mean_review', ascending=False)
df = df_sorted
df.head(5)
# Out:
#                                             course_name          instructor  \
# 4704           SQL SERVER ADMINISTRATION: GETTING A JOB      Raphael Asghar
# 3287  Mastering critical SKILLS in Algorithms using ...      GetSkilled Org
# 4605  27hrs Data Structures +Algorithms StackQueueLi...  Sonali Shrivastava
# 4969  Build A Blog Using AspNet Core, Angular 14 And...    Avetis Ghukasyan
# 4837  Brick Breaker Game in most Powerful C++ graphi...         Khan School
#
#                                              course url  \
# 4704  https://www.udemy.com/course/sql-server-admini...
# 3287  https://www.udemy.com/course/skills-algorithms...
# 4605  https://www.udemy.com/course/27hrs-datastructu...
# 4969  https://www.udemy.com/course/learn-web-develop...
# 4837  https://www.udemy.com/course/brick-breaker-gam...
#
#                                            course image  \
# 4704  https://img-b.udemycdn.com/course/240x135/8739...
# ...

# %%
for description in df['course description'].head():
    print(description)
# Out:
# A personal guide on how to secure a SQL Server Administration Job and the requisites the student needs
# Part 1 and 2 have 140 Challenges and solutions to sharpen your problem-solving skills and smooth interviews preparations
# Master Data Structures & Algorithms The Ultimate Coding Interview Bootcamp - Get more job offers
# Use Angular, Bootstrap, Asp.Net Core, SQL Server & learn full stack web development by building a blogging application.
# English

# %%
import matplotlib.pyplot as plt


plt.hist(df['Mean_review'], bins=20)
plt.xlabel('Course Ratings')
plt.ylabel('Frequency')
plt.title('Distribution of Course Ratings')
plt.show()


plt.hist(df['course_duration'], bins=20)
plt.xlabel('Course Duration')
plt.ylabel('Frequency')
plt.title('Distribution of Course Durations')
plt.show()


plt.hist(df['Duration of lectures'], bins=20)
plt.xlabel('Number of Lectures')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Lectures')
plt.show()

# %%
df.head()
# Out:
#                                             course_name          instructor  \
# 4704           SQL SERVER ADMINISTRATION: GETTING A JOB      Raphael Asghar
# 3287  Mastering critical SKILLS in Algorithms using ...      GetSkilled Org
# 4605  27hrs Data Structures +Algorithms StackQueueLi...  Sonali Shrivastava
# 4969  Build A Blog Using AspNet Core, Angular 14 And...    Avetis Ghukasyan
# 4837  Brick Breaker Game in most Powerful C++ graphi...         Khan School
#
#                                              course url  \
# 4704  https://www.udemy.com/course/sql-server-admini...
# 3287  https://www.udemy.com/course/skills-algorithms...
# 4605  https://www.udemy.com/course/27hrs-datastructu...
# 4969  https://www.udemy.com/course/learn-web-develop...
# 4837  https://www.udemy.com/course/brick-breaker-gam...
#
#                                            course image  \
# 4704  https://img-b.udemycdn.com/course/240x135/8739...
# ...

# %%
df.shape
# Out:
# (4999, 11)

# %%
for url in df['course url'].head() :
  print(url)
# Out:
# https://www.udemy.com/course/sql-server-administration-getting-a-job/
# https://www.udemy.com/course/skills-algorithms-cpp/
# https://www.udemy.com/course/27hrs-datastructure-algorithm-cc-stack-queue-linkedlist/
# https://www.udemy.com/course/learn-web-development-by-building-a-blog/
# https://www.udemy.com/course/brick-breaker-game-in-most-powerful-c-graphic-library-sdl2/

# %%
df.columns
# Out:
# Index(['course_name', 'instructor', 'course url', 'course image',
#        'course description', 'Mean_review', 'Number_of_reviews',
#        'course_duration', 'Duration of lectures', 'level',
#        'Number of Students'],
#       dtype='object')

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from googleapiclient.discovery import build

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Function to preprocess text
def preprocess_text(text):
    tokens = word_tokenize(text.lower())  # Tokenization and convert to lowercase
    tokens = [token for token in tokens if token.isalnum()]  # Remove non-alphanumeric tokens
    tokens = [token for token in tokens if token not in stopwords.words('english')]  # Remove stopwords
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]  # Lemmatization
    return ' '.join(tokens)

# Function to search YouTube videos
def search_youtube_videos(api_key, keywords):
    youtube = build('youtube', 'v3', developerKey=api_key)
    request = youtube.search().list(
        q=' '.join(keywords),
        part='snippet',
        type='video',
        maxResults=10
    )
    response = request.execute()
    return response['items']

# Function to retrieve video details
def get_video_details(video_ids):
    youtube = build('youtube', 'v3', developerKey=api_key)
    request = youtube.videos().list(
        part='snippet,statistics',
        id=','.join(video_ids)
    )
    response = request.execute()
    return response['items']

# Function to present recommendations for YouTube videos
def present_recommendations(recommended_videos):
    for video in recommended_videos:
        print("Title:", video['snippet']['title'])
        print("Description:", video['snippet']['description'])
        print("Views:", video['statistics']['viewCount'])
        print("Link: https://www.youtube.com/watch?v=" + video['id'] + "\n")

# Define the PDF text
pdf_text = "Deep learning"
preprocessed_pdf_text = preprocess_text(pdf_text)

# Calculate TF-IDF vectors for course descriptions and PDF text
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df['cleaned_description'].values)
pdf_tfidf = tfidf_vectorizer.transform([preprocessed_pdf_text])

# Calculate cosine similarity between PDF text and course descriptions
similarities = cosine_similarity(pdf_tfidf, tfidf_matrix)

# indices of top similar courses
top_indices = similarities.argsort(axis=1)[:, -5:][:, ::-1]

# top recommended courses
top_courses = df.iloc[top_indices.flatten()]

# Print top recommended courses
print(top_courses[['course_name', 'instructor', 'course url']])

# Define the YouTube API key
api_key = "AIzaSyAKXKLWqwllEDfqYU9SKMDEHIlHyJurwCQ"

# Call search_youtube_videos function to find relevant videos
videos = search_youtube_videos(api_key, preprocessed_pdf_text)


# Get video IDs
video_ids = [video['id']['videoId'] for video in videos]

# Get video details
video_details = get_video_details(video_ids)

# Recommend videos with most views
recommended_videos = sorted(video_details, key=lambda x: int(x['statistics']['viewCount']), reverse=True)

# Present recommendations for YouTube videos
present_recommendations(recommended_videos)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                        course_name  \
# 916                           Practical Deep Learning with PyTorch
# 4687               Complete Deep Learning In R With Keras & Others
# 474                 PyTorch for Deep Learning with Python Bootcamp
# 3933                                        Programming with Julia
# 1382  [2022] Machine Learning and Deep Learning Bootcamp in Python
#
#                 instructor  \
# 916   Deep Learning Wizard
# 4687         Minerva Singh
# 474          Jose Portilla
# 3933      Dr. İlker Arslan
# 1382        Holczer Balazs
#
# ...
